# %%
# ******************************************** Practice_Dataset ***********************************************************************************

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""

Q.1> Import "movies.csv" into python using appropriate packages. 

Extract title, budget, revenue_msusd, production_companies, runtime, cast_size from the imported dataset. Remove missing values from the dataset. 

Print top 20 rows for columns title, budget, and runtime.

Q.2> Impute median in missing data of vote_average column in dataset and then perform an Outlier detection on it.
create a box-plot for the same.

Q.3> Find the column which has maximum missing data in it.
For that column update the missing data with the mean of the “cast_size” value.

Q.4> Calculate Mean, Median, Mode, Quartile Ranges, Sd of Runtime for where “spoken_languages” column contains only English, where crew_size > cast_size.

"""
# Out:
# '\n\nQ.1> Import "movies.csv" into python using appropriate packages. \n\nExtract title, budget, revenue_msusd, production_companies, runtime, cast_size from the imported dataset. Remove missing values from the dataset. \n\nPrint top 20 rows for columns title, budget, and runtime.\n\nQ.2> Impute median in missing data of vote_average column in dataset and then perform an Outlier detection on it.\ncreate a box-plot for the same.\n\nQ.3> Find the column which has maximum missing data in it.\nFor that column update the missing data with the mean of the “cast_size” value.\n\nQ.4> Calculate Mean, Median, Mode, Quartile Ranges, Sd of Runtime for where “spoken_languages” column contains only English, where crew_size > cast_size.\n\n'

# %%
# ************************* Q.1 *****************************************

# %%
# Q.1> Import movies.csv into python using appropriate packages. 

df = pd.read_csv("movies.csv")
df.T
# Out:
#                                                                    0      \
# id                                                                   862
# title                                                          Toy Story
# tagline                                                              NaN
# release_date                                                  1995-10-30
# genres                                           Animation|Comedy|Family
# belongs_to_collection                               Toy Story Collection
# original_language                                                     en
# budget_musd                                                         30.0
# revenue_musd                                                  373.554033
# production_companies                             Pixar Animation Studios
# production_countries                            United States of America
# vote_count                                                        5415.0
# ...

# %%
# Extract title, budget, revenue_msusd, production_companies, runtime, cast_size from the imported dataset.

new_df = df[['title', 'budget_musd', 'revenue_musd', 'runtime','cast_size']]
new_df
# Out:
#                              title  budget_musd  revenue_musd  runtime  \
# 0                        Toy Story         30.0    373.554033     81.0
# 1                          Jumanji         65.0    262.797249    104.0
# 2                 Grumpier Old Men          NaN           NaN    101.0
# 3                Waiting to Exhale         16.0     81.452156    127.0
# 4      Father of the Bride Part II          NaN     76.578911    106.0
# ...                            ...          ...           ...      ...
# 44686                       Subdue          NaN           NaN     90.0
# 44687          Century of Birthing          NaN           NaN    360.0
# 44688                     Betrayal          NaN           NaN     90.0
# 44689             Satan Triumphant          NaN           NaN     87.0
# 44690                     Queerama          NaN           NaN     75.0
#
#        cast_size
# 0             13
# 1             26
# 2              7
# 3             10
# 4             12
# ...

# %%
# Remove missing values from the dataset.

print("remove missing value: ")
remove_miss = new_df.dropna()
print(remove_miss.isnull().sum())
#print(remove_miss)
# Out:
# remove missing value:
# title           0
# budget_musd     0
# revenue_musd    0
# runtime         0
# cast_size       0
# dtype: int64

# %%
# Print top 20 rows for columns title, budget, and runtime.

#new_df = df[["title", "budget_musd", "runtime"]]
print(new_df.head(20))
# Out:
#                              title  budget_musd  revenue_musd  runtime  \
# 0                        Toy Story         30.0    373.554033     81.0
# 1                          Jumanji         65.0    262.797249    104.0
# 2                 Grumpier Old Men          NaN           NaN    101.0
# 3                Waiting to Exhale         16.0     81.452156    127.0
# 4      Father of the Bride Part II          NaN     76.578911    106.0
# 5                             Heat         60.0    187.436818    170.0
# 6                          Sabrina         58.0           NaN    127.0
# 7                     Tom and Huck          NaN           NaN     97.0
# 8                     Sudden Death         35.0     64.350171    106.0
# 9                        GoldenEye         58.0    352.194034    130.0
# 10          The American President         62.0    107.879496    106.0
# 11     Dracula: Dead and Loving It          NaN           NaN     88.0
# ...

# %%
# ************************* Q.2) ****************************************

# %%
# Impute median in missing data of vote_average column in dataset and then perform an Outlier detection on it and create a box-plot for the same.

# impute => find the value and then replace the missing value with that value;
print("the median of the vote_average: ", df["vote_average"].median())   # q2

df["vote_average"].fillna(df["vote_average"].median(), inplace=True)

# find q1 and q3;
q1 = df["vote_average"].quantile(0.25)
q3 = df["vote_average"].quantile(0.75)

#find iqr:
iqr = d3 = q1

# find lower and upper boundary:
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# apply outliers condition;
outliers = (df["vote_average"] < lower_bound) | (df["vote_average"] > upper_bound)

# plot scatter:
plt.boxplot(x = df["vote_average"], data= "new_df")
plt.show()
# Out:
# the median of the vote_average:  6.1

# %%
# Q.3) find the column which has maximum missing data in it. 
# For that column update the missing data with the mean of the “cast_size” value.

new_df.isnull().sum()
# Out:
# title               0
# budget_musd     35837
# revenue_musd    37306
# runtime          1512
# cast_size           0
# dtype: int64

# %%
mean_cast_size = new_df["cast_size"].mean()
new_df["revenue_musd"].fillna(mean_cast_size,inplace = True)
new_df
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_30864\3964482899.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["revenue_musd"].fillna(mean_cast_size,inplace = True)
#                              title  budget_musd  revenue_musd  runtime  \
# 0                        Toy Story         30.0    373.554033     81.0
# 1                          Jumanji         65.0    262.797249    104.0
# 2                 Grumpier Old Men          NaN     12.479090    101.0
# 3                Waiting to Exhale         16.0     81.452156    127.0
# 4      Father of the Bride Part II          NaN     76.578911    106.0
# ...                            ...          ...           ...      ...
# 44686                       Subdue          NaN     12.479090     90.0
# ...

# %%
# Q.4> Calculate Mean, Median, Mode, Quartile Ranges, Std deviation of Runtime for where “spoken_languages” column contains only English, where crew_size > cast_size.


run_df = df[(df["spoken_languages"] == "English") & (df["crew_size"] > df["cast_size"])]
#print(run_df)

print("the mean is: ",run_df["runtime"].mean())
print("The median is: ",run_df["runtime"].median())
print("The mode is: ",run_df["runtime"].mode())
print("the standard deviation: ",run_df["runtime"].std())
print("the quantile range is: ",run_df["runtime"].quantile())
# Out:
# the mean is:  93.524015577672
# The median is:  93.0
# The mode is:  0    90.0
# Name: runtime, dtype: float64
# the standard deviation:  34.87911125741443
# the quantile range is:  93.0
