# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
candidate2009 = pd.read_csv("LS2009Candidate.csv")
candidate2009
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 1        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 2        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 3        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 4        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8065     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8066     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8067     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8068     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8069     U07      Puducherry      3  2009          1  Puducherry     GEN
#
#               Candidate Name Candidate Sex Candidate Category  Candidate Age  \
# ...

# %%
candidate2014 = pd.read_csv("LS2014Candidate.csv")
candidate2014
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 1        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 2        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 3        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 4        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8789     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8790     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8791     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8792     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8793     U07      Puducherry      5  2014          1  Puducherry     GEN
#
#                     Candidate Name Candidate Sex Candidate Category  \
# ...

# %%
elector2009 = pd.read_csv("LS2009Electors.csv")
elector2009
# Out:
#     STATE CODE           STATE  PC NO PARLIAMENTARY CONSTITUENCY  \
# 0          S01  Andhra Pradesh      1                   Adilabad
# 1          S01  Andhra Pradesh      2                 Peddapalle
# 2          S01  Andhra Pradesh      3                 Karimnagar
# 3          S01  Andhra Pradesh      4                  Nizamabad
# 4          S01  Andhra Pradesh      5                  Zahirabad
# ..         ...             ...    ...                        ...
# 538        U05    NCT OF Delhi      5          NORTH WEST  DELHI
# 539        U05    NCT OF Delhi      6                WEST  DELHI
# 540        U05    NCT OF Delhi      7                SOUTH DELHI
# 541        U06     Lakshadweep      1                Lakshadweep
# 542        U07      Puducherry      1                 Puducherry
#
#      Total voters  Total_Electors  TOT_CONTESTANT  POLL PERCENTAGE
# 0          864165         1131211               9            76.39
# ...

# %%
electors2014 = pd.read_csv("LS2014Electors.csv")
electors2014
# Out:
#     STATE CODE           STATE  PC NO      PARLIAMENTARY CONSTITUENCY  \
# 0          S01  Andhra Pradesh      1                       Adilabad
# 1          S01  Andhra Pradesh      2                     Peddapalle
# 2          S01  Andhra Pradesh      3                     Karimnagar
# 3          S01  Andhra Pradesh      4                       Nizamabad
# 4          S01  Andhra Pradesh      5                       Zahirabad
# ..         ...             ...    ...                             ...
# 538        U05    NCT OF Delhi      5  NORTH WEST DELHI
# 539        U05    NCT OF Delhi      6  WEST DELHI
# 540        U05    NCT OF Delhi      7  SOUTH DELHI
# 541        U06     Lakshadweep      1                     Lakshadweep
# 542        U07      Puducherry      1                      Puducherry
#
#      Total voters  Total_Electors  POLL PERCENTAGE
# 0         1055593         1386282            76.15
# 1         1025194         1425355            71.93
# ...

# %%
'''
1. Create grand alliances
a. 'INC','NCP', 'RJD', 'DMK', 'IUML',
'JMM','JD(s)','KC(M)','RLD','RSP','CMP(J)','KC(J)','PPI','MD' as UPA
b. 'BJP','SS', 'LJP', 'SAD', 'RLSP',
'AD','PMK','NPP','AINRC','NPF','RPI(A)','BPF','JD(U)','SDF','NDPP','MNF','RIDALOS','KM
DK','IJK','PNK','JSP','GJM','MGP','GFP','GVP','AJSU','IPFT','MPP','KPP','JKPC','KC(T)','BDJ
S','AGP','JSS','PPA','UDP','HSPDP','PSP','JRS','KVC','PNP','SBSP','KC(N)','PDF','MDPF' as
NDA
c. 'YSRCP','AAAP', 'IND', 'AIUDF', 'BLSP', 'JKPDP', 'JD(S)', 'INLD', 'CPI', 'AIMIM',
'KEC(M)','SWP', 'NPEP', 'JKN', 'AIFB', 'MUL', 'AUDF', 'BOPF', 'BVA', 'HJCBL',
'JVM','MDMK' as Others

'''
# Out:
# "\n1. Create grand alliances\na. 'INC','NCP', 'RJD', 'DMK', 'IUML',\n'JMM','JD(s)','KC(M)','RLD','RSP','CMP(J)','KC(J)','PPI','MD' as UPA\nb. 'BJP','SS', 'LJP', 'SAD', 'RLSP',\n'AD','PMK','NPP','AINRC','NPF','RPI(A)','BPF','JD(U)','SDF','NDPP','MNF','RIDALOS','KM\nDK','IJK','PNK','JSP','GJM','MGP','GFP','GVP','AJSU','IPFT','MPP','KPP','JKPC','KC(T)','BDJ\nS','AGP','JSS','PPA','UDP','HSPDP','PSP','JRS','KVC','PNP','SBSP','KC(N)','PDF','MDPF' as\nNDA\nc. 'YSRCP','AAAP', 'IND', 'AIUDF', 'BLSP', 'JKPDP', 'JD(S)', 'INLD', 'CPI', 'AIMIM',\n'KEC(M)','SWP', 'NPEP', 'JKN', 'AIFB', 'MUL', 'AUDF', 'BOPF', 'BVA', 'HJCBL',\n'JVM','MDMK' as Others\n\n"

# %%
# create grand alliances:
UPA = ['INC','NCP', 'RJD', 'DMK', 'IUML','JMM','JD(s)','KC(M)','RLD','RSP','CMP(J)','KC(J)','PPI','MD']
NDA = ['BJP','SS', 'LJP', 'SAD', 'RLSP','AD','PMK','NPP','AINRC','NPF','RPI(A)','BPF','JD(U)','SDF','NDPP','MNF','RIDALOS','KMDK','IJK','PNK','JSP','GJM','MGP','GFP','GVP','AJSU','IPFT','MPP','KPP','JKPC','KC(T)','BDJS','AGP','JSS','PPA','UDP','HSPDP','PSP','JRS','KVC','PNP','SBSP','KC(N)','PDF','MDPF']
Others = ['YSRCP','AAAP', 'IND', 'AIUDF', 'BLSP', 'JKPDP', 'JD(S)', 'INLD', 'CPI', 'AIMIM','KEC(M)','SWP', 'NPEP', 'JKN', 'AIFB', 'MUL', 'AUDF', 'BOPF', 'BVA', 'HJCBL', 'JVM','MDMK']

# %%
# add alliences col to the 2009;

candidate2009["Alliences"] = candidate2009["Party Abbreviation"].apply(lambda x: "UPA" if x in UPA else "NDA" if x in NDA else "Others")
candidate2014["Alliences"] = candidate2014["Party Abbreviation"].apply(lambda x: "UPA" if x in UPA else "NDA" if x in NDA else "Others")

candidate2014
# Out:
#      ST_CODE      State name  Month  Year  PC Number     PC name PC Type  \
# 0        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 1        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 2        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 3        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# 4        S01  Andhra Pradesh      5  2014          1   Adilabad       ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8789     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8790     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8791     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8792     U07      Puducherry      5  2014          1  Puducherry     GEN
# 8793     U07      Puducherry      5  2014          1  Puducherry     GEN
#
#                     Candidate Name Candidate Sex Candidate Category  \
# ...

# %%
# find out the counts for alliances:

# %%
candidate2009["Alliences"].value_counts()
candidate2014["Alliences"].value_counts()
# Out:
# Alliences
# Others    7530
# NDA        634
# UPA        630
# Name: count, dtype: int64

# %%
# 2. Create Winning seats distribution by Major Political Parties & Alliances for 2009 & 2014

new_df_candidate2009 = candidate2009[candidate2009["Position"] == 1]
new_df_candidate2014 = candidate2014[candidate2014["Position"] == 1]
new_df_candidate2014
# Out:
#      ST_CODE      State name  Month  Year  PC Number  \
# 0        S01  Andhra Pradesh      5  2014          1
# 9        S01  Andhra Pradesh      5  2014          2
# 27       S01  Andhra Pradesh      5  2014          3
# 45       S01  Andhra Pradesh      5  2014          4
# 62       S01  Andhra Pradesh      5  2014          5
# ...      ...             ...    ...   ...        ...
# 8703     U05    NCT OF Delhi      5  2014          5
# 8718     U05    NCT OF Delhi      5  2014          6
# 8736     U05    NCT OF Delhi      5  2014          7
# 8756     U06     Lakshadweep      5  2014          1
# 8763     U07      Puducherry      5  2014          1
#
#                              PC name PC Type             Candidate Name  \
# 0                          Adilabad       ST               GODAM NAGESH
# 9                        Peddapalle       SC                BALKA SUMAN
# 27                       Karimnagar      GEN     VINOD KUMAR BOINAPALLY
# ...

# %%
# count plot for each alliances:

fig, ax = plt.subplots(figsize=(8, 6))
sns.countplot(x= new_df_candidate2009['Alliences'])
ax.bar_label(ax.containers[-1], fmt='Count:\n%.2f', label_type='center')
plt.title(" Seats distribution by Major Political Parties & Alliances for 2009")
plt.show()

fig,ax = plt.subplots(figsize = (8,6))
sns.countplot(x = new_df_candidate2014["Alliences"])
ax.bar_label(ax.containers[-1], fmt = "count: \n %.2f", label_type = "center")
plt.title(" Seats distribution by Major Political Parties & Alliances for 2014")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # count plot for each alliances:
# ----> 3 fig, ax = plt.subplots(figsize=(8, 6))
#       4 sns.countplot(x= new_df_candidate2009['Alliences'])
#       5 ax.bar_label(ax.containers[-1], fmt='Count:\n%.2f', label_type='center')
#
# NameError: name 'plt' is not defined

# %%
# 4. Plot comparatively seats won based on candidate category as General, ST and SC for 2009 & 2014

fig,ax = plt.subplots(figsize =(8,6))
sns.countplot(x = new_df_candidate2009["Candidate Category"] )
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f", label_type = "center")
plt.title("seats won based on candidate category")
plt.show()


fig, ax = plt.subplots(figsize = (8,6))
sns.countplot(x = new_df_candidate2014["Candidate Category"])
ax.bar_label(ax.containers[-1], fmt="count: \n%.1f", label_type = "center")
plt.title("seats won based on candidate category")
plt.show()

# %%
new_df_candidate2014
# Out:
#      ST_CODE      State name  Month  Year  PC Number  \
# 0        S01  Andhra Pradesh      5  2014          1
# 9        S01  Andhra Pradesh      5  2014          2
# 27       S01  Andhra Pradesh      5  2014          3
# 45       S01  Andhra Pradesh      5  2014          4
# 62       S01  Andhra Pradesh      5  2014          5
# ...      ...             ...    ...   ...        ...
# 8703     U05    NCT OF Delhi      5  2014          5
# 8718     U05    NCT OF Delhi      5  2014          6
# 8736     U05    NCT OF Delhi      5  2014          7
# 8756     U06     Lakshadweep      5  2014          1
# 8763     U07      Puducherry      5  2014          1
#
#                              PC name PC Type             Candidate Name  \
# 0                          Adilabad       ST               GODAM NAGESH
# 9                        Peddapalle       SC                BALKA SUMAN
# 27                       Karimnagar      GEN     VINOD KUMAR BOINAPALLY
# ...

# %%
# 5. Plot the age distribution of winners of both 2014 and 2009 elections

fig, ax = plt.subplots(figsize = (8,6))
sns.histplot(x = new_df_candidate2014["Candidate Age"], bins = 10)
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f", label_type = "center")
plt.title("age distribution of winners of 2014 ")
plt.show()


fig,ax = plt.subplots(figsize =(8,6))
sns.histplot(x = new_df_candidate2009["Candidate Age"], bins =10)
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f")
plt.title("age distribution of winners of 2009 ")
plt.show()
# Out:
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 6. Separately plot age distribution of NDA & UPA candidates


fig,ax = plt.subplots(figsize=(8,6))

sns.histplot(x = new_df_candidate2009[new_df_candidate2009["Alliences"] == "NDA"]["Candidate Age"], bins = 10)
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f",label_type = "center")
plt.title("Separately plot age distribution of NDA candidates in 2009")
plt.show()


fig,ax = plt.subplots(figsize=(8,6))
sns.histplot(x = new_df_candidate2009[new_df_candidate2009["Alliences"] == "UPA"]["Candidate Age"], bins = 10)
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f",label_type = "center")
plt.title("Separately plot age distribution of UPA candidates in 2009")
plt.show()


fig,ax = plt.subplots(figsize=(8,6))
sns.histplot(x = new_df_candidate2014[new_df_candidate2014["Alliences"]=="UPA"]["Candidate Age"], bins = 10)
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f", label_type = "center")
plt.title("Separately plot age distribution of UPA candidates in 2014")
plt.show()


fig,ax = plt.subplots(figsize=(8,6))
sns.histplot(x = new_df_candidate2014[new_df_candidate2014["Alliences"]=="NDA"]["Candidate Age"], bins = 10)
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f", label_type = "center")
plt.title("Separately plot age distribution of NDA candidates in 2014")
plt.show()
# Out:
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# 7. Plot Gender distributions of 2009 & 2014 elections


fig,ax = plt.subplots(figsize=(8,6))
sns.countplot(x = new_df_candidate2014["Candidate Sex"])
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f", label_type = "center")
plt.title("Gender distributions of 2014")
plt.show()


fig,ax = plt.subplots(figsize=(8,6))
sns.countplot(x = new_df_candidate2009["Candidate Sex"])
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f", label_type = "center")
plt.title("Gender distributions of 2009")
plt.show()

# %%
# 8.Plot gender distribution of NDA and UPA separately for 2009 elections

fig, ax= plt.subplots(figsize = (8,6))
sns.countplot(x = new_df_candidate2009[new_df_candidate2009["Alliences"] == "NDA"]["Candidate Sex"])
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f", label_type = "center")
plt.title("gender distribution of NDA in 2009")
plt.show()

fig, ax= plt.subplots(figsize = (8,6))
sns.countplot(x = new_df_candidate2009[new_df_candidate2009["Alliences"] == "UPA"]["Candidate Sex"])
ax.bar_label(ax.containers[-1], fmt = "count: \n%.2f", label_type = "center")
plt.title("gender distribution of UDA in 2009")
plt.show()

# %%
# 10. Plot the poll percentage of states for 2009 & 2014 elections

#total_poll = new_df_candidate2009.groupby(["ST_CODE"])["Total Votes Polled"].sum()
#total_poll.sum()

# %%
#print((total_poll.loc['S01']/total_vote)*100)
#total_poll_vote_by_state

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x=elector2009['STATE'],y= elector2009['POLL PERCENTAGE'])
plt.title("the poll percentage of states for 2009")
plt.xticks(rotation = 90)
plt.show()


fig, ax = plt.subplots(figsize=(12, 10))
sns.barplot(x=electors2014['STATE'],y= electors2014['POLL PERCENTAGE'])
plt.title("The poll percentage of states for 2014")
plt.xticks(rotation = 90)
plt.show()
