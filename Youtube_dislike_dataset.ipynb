# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("youtube_dislike_dataset (1).csv")
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
# display row and cols;

df.shape
# Out:
# (37422, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
# show count of non null values in each col
df.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
# check garbage value ==> any special character

for i in df.select_dtypes(include = "object"):
    print(df[i].value_counts())
    
    print("*************")
# Out:
# video_id
# --0bCF-iK2E    1
# eb956E3RXfo    1
# eZc0O5Czg40    1
# e_G6eM2oq90    1
# e_Ou-HUCQ9Q    1
#               ..
# K8qeRtOPDqs    1
# K8xAit6W3Rs    1
# K95MIzDth_A    1
# K96S2qroRN4    1
# zzxPZwaA-8w    1
# Name: count, Length: 37422, dtype: int64
# *************
# title
# www                                                                                                    21
# Starlink Mission                                                                                       20
# wwww                                                                                                    9
# vs                                                                                                      9
# Most Oddly Satisfying Video to watch before sleep                                                       9
#                                                                                                        ..
# ...

# %%
# diplay basic opeartions on each col"
df.describe().T
# Out:
#                  count          mean           std      min       25%  \
# view_count     37422.0  5.697838e+06  2.426622e+07  20368.0  512297.0
# likes          37422.0  1.668147e+05  5.375670e+05      0.0   13233.5
# dislikes       37422.0  4.989862e+03  3.070824e+04      0.0     281.0
# comment_count  37422.0  9.924930e+03  1.171003e+05      0.0     900.0
#
#                      50%         75%           max
# view_count     1319078.5  3670231.25  1.322797e+09
# likes            42330.5   130469.75  3.183768e+07
# dislikes           796.0     2461.75  2.397733e+06
# comment_count     2328.0     6184.00  1.607103e+07

# %%
# Histogram:


for i in df.select_dtypes(include = "number"):
    sns.histplot(data = df, x = i)
    plt.show()
# Out:
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# histogram is not looking good ==> plot kde plot

for i in df.select_dtypes(include = "number"):
    plt.figure(figsize=(15,6)),
    sns.kdeplot(data = df, x =i)
    plt.show()
# Out:
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Rohit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Boxplot: ==> outllier detection

for i in df.select_dtypes(include = "number"):
    sns.boxplot(data = df, x = i)
    plt.show()

# %%
# Bivariate analysis:

# scatter plot:

for i in ["view_count","likes", "comment_count"]:
    sns.scatterplot(data = df, x = i, y = "likes")
    plt.show()

# %%
for i in ["view_count","likes", "comment_count"]:
    sns.scatterplot(data = df, x = i, y = "likes")
    plt.show()

# %%
for i in df.select_dtypes(include = "number"):
    sns.lmplot(data = df, x=i, y = "likes")
    plt.show()

# %%
# correlation :
# heatmap
 
co = df.select_dtypes(include = "number").corr()
for i in df.select_dtypes(include = "number"):
    sns.heatmap(data = co, annot = True)
    plt.show()

# %%
df.dropna(inplace = True)    # will remove null values
df.isnull().sum()

# feature engginering;  ==> creating extra feature;

# convert published at ==> date with extra feature
df["date"] = pd.to_datetime(df["published_at"])

df.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at             object
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# date             datetime64[ns]
# dtype: object

# %%
df["month"] = df["date"].dt.month_name()
df["month"]
# Out:
# 0             July
# 1             June
# 2        September
# 3            March
# 4         December
#            ...
# 37417     February
# 37418      January
# 37419         June
# 37420      October
# 37421          May
# Name: month, Length: 37264, dtype: object

# %%
df["year"] = df["date"].dt.year
df["year"]
# Out:
# 0        2021
# 1        2021
# 2        2021
# 3        2021
# 4        2021
#          ...
# 37417    2021
# 37418    2021
# 37419    2021
# 37420    2020
# 37421    2021
# Name: year, Length: 37264, dtype: int32

# %%
df.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at             object
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# date             datetime64[ns]
# month                    object
# year                      int32
# dtype: object

# %%
# Documents of insights;

# missing value is treated , 
# there is outlier in data,
# there is best relationshop likes, comments, and the views;
